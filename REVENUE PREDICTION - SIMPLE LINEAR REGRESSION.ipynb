# %% [markdown]
# # REVENUE PREDICTION - SIMPLE LINEAR REGRESSION

# %% [markdown]
# PROBLEM STATEMENT
# You own an ice cream business and you would like to create a model that could predict the daily revenue in dollars based on the outside air temperature (degC). You decide that a Linear Regression model might be a good candidate to solve this problem.
# Data set:
#
# Independant variable X: Outside Air Temperature
# Dependant variable Y: Overall daily revenue generated in dollars

# %%
#import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
###  IMPORT DATASET ###

IceCream = pd.read_csv(r"F:\tutuh 56.5   85gb\machine learning codes\Linear Regression-Predicting Revenue\IceCreamData.csv")
IceCream.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
IceCream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
IceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
#visualize data set
sns.jointplot(x='Temperature', y='Revenue', data = IceCream)
sns.pairplot(IceCream)
sns.lmplot(x='Temperature', y='Revenue', data=IceCream)

# %%
## CREATE TESTING AND TRAINING DATASET

y = IceCream['Revenue']
X = IceCream[['Temperature']]

# %%
sns.pairplot(IceCream)

# %%
sns.regplot(x='Temperature', y='Revenue', data = IceCream)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Revenue'>

# %%
#splitting the data into train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
# Train linear regression
from sklearn.linear_model import LinearRegression

#instatiation of an object out of our class
#when "fit_intercept = True" - asking the model to obtain intercept which is value of 'm' and 'b'
#when "fit_intercept = False" - model will obtain only the 'm' value; 'b' will be zero by default
regressor = LinearRegression(fit_intercept =True)
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', regressor.coef_)
print('Linear Model Coefficient (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (m):  [21.33236203]
# Linear Model Coefficient (b):  47.19991238076733

# %%
#Test the model
y_predict = regressor.predict( X_test)
y_predict
# Out:
# array([685.44944073, 447.75404093, 732.11976438, 609.03145074,
#        203.68228094, 662.97110613, 736.97774458, 941.54738247,
#        672.49437598, 671.1954491 , 658.35484613, 801.50712665,
#        592.15569752, 767.04358885, 177.19713374, 378.30295655,
#        627.19520312, 191.73106629, 245.79024298, 428.43480089,
#        239.59350405, 565.75327727, 530.05227497, 520.55469866,
#        410.91108763, 704.96163774, 713.38800053, 614.53523364,
#        803.31580441, 469.14056305, 451.50194473, 519.76695426,
#        423.43743248, 453.93533708, 502.05690581, 519.63316558,
#        529.72334466, 684.61031136, 563.10041737, 412.68290605,
#        461.75741293, 569.25469502, 572.30109498, 743.33585658,
#        452.04529002, 569.52084738, 285.86119119, 556.65351134,
#        642.09785727, 151.00049009, 469.0505439 , 452.05188407,
#        680.86029864, 521.31426706, 446.29589676, 634.19495972,
#        525.0016725 , 447.68369832, 388.35445174, 745.11758921,
#        590.07098114, 576.64254872, 861.78040918, 516.72251944,
#        396.61489867, 422.09984773, 546.64485814, 613.15214397,
#         47.19991238, 294.00773973, 668.59301186, 497.93406931,
#        467.90249548, 442.02695684, 283.11656288, 397.179091  ,
#        304.52100184, 442.95020312, 545.28996282, 803.60571078,
#        353.56301164, 722.78439616, 438.5809051 , 575.78757709,
#        661.30390887, 456.84462115, 440.56827638, 611.56996598,
#        607.1903271 , 526.06949866, 450.10768246, 388.96515993,
#        800.8980363 , 638.21426599, 182.71287543, 938.17991233,
#        351.97954859, 501.19344944, 627.13746005, 798.46682732,
#        807.24903865, 495.74264973, 582.89958969, 795.85479649,
#        485.8575892 , 450.03424089, 550.1554279 , 722.76349834,
#        505.59347502, 444.70528758, 570.30882452, 682.22643292,
#        592.26736177, 495.3298041 , 415.44300949, 756.19530605,
#        292.59668867, 548.45777378, 520.16395336, 308.96861757,
#        441.05732397, 510.04353587, 317.87408729, 546.53199224,
#        711.91695796])

# %%
#VISUALIZE TRAIN SET RESULTS
plt.scatter(X_train, y_train, color = 'red')
plt.scatter(X_train, regressor.predict(X_train), color = 'blue')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')

# %%
#VISUALIZE TEST SET RESULTS
plt.scatter(X_test, y_test, color = 'red')
plt.scatter(X_test, regressor.predict(X_test), color = 'blue')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Hours')
plt.title('Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')

# %%
y_predict = regressor.predict([[30]])   #regressor.predict(30)
y_predict
# Out:
# C:\Users\Budda Reddy\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([687.17077334])
